# %%
dsa_learner="Chethan"
print(dsa_learner)
# Out:
# Chethan

# %%
ad=dsa_learner+"trying hard to find time"
print(ad)
# Out:
# Chethantrying hard to find time

# %%
print(type(ad))
# Out:
# <class 'str'>

# %%
# print(list(ad))
print(ad[-15:])
# Out:
# rd to find timerd to find time

# %%
n=3
if n==1:
    print("Python beginer")
elif n==3:
    print("Python interpreter")
else:
    print("yet to start")
# Out:
# Python interpreter

# %%
#note: we can multiply the string but we cant add int

# %%
if 1+2==4:
    print(True)
else:
    print(False)
# Out:
# False
