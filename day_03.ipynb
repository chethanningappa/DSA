# %%
boxs=[10,28,5,10,5,5,10,5,21,32,12,5,5,5]
count=0
for i in boxs:
    if i==5:
        count+=1
print(count)
# Out:
# 7

# %%
#indices
boxs[0]
boxs[-2]
# Out:
# 5

# %%
for i in range(5):
    print(boxs[i])
# Out:
# 10
# 28
# 5
# 10
# 5

# %%
len(boxs)
# Out:
# 14

# %%
for i in range(len(boxs)):
    print(boxs[i])
# Out:
# 10
# 28
# 5
# 10
# 5
# 5
# 10
# 5
# 21
# 32
# 12
# 5
# 5
# 5

# %%
print(list(range(7)))
'''range will give values from 0 to 6, it will give dimension less than 1 means start from 0 go till (n-1), nth value not included'''
# Out:
# [0, 1, 2, 3, 4, 5, 6]
# 'range will give values from 0 to 6, it will give dimension less than 1'

# %%
print(range(7))
# Out:
# range(0, 7)

# %%
print(list(range(5,7)))
# Out:
# [5, 6]

# %%
print(list(range(2,10,-1)))
# Out:
# []

# %%
print(list(range(22,10,-2)))
# Out:
# [22, 20, 18, 16, 14, 12]

# %%
boxs=[10,28,5,10,5,5,10,5,21,32,12,5,5,5]

# %%
boxs = [10, 28, 5, 10, 5, 5, 10, 5, 21, 32, 12, 5, 5, 5]

for i in range(len(boxs)):
    print(boxs[i])
# Out:
# 10
# 28
# 5
# 10
# 5
# 5
# 10
# 5
# 21
# 32
# 12
# 5
# 5
# 5

# %%
for i, value in enumerate(boxs):
    print(i, value)
# Out:
# 0 10
# 1 28
# 2 5
# 3 10
# 4 5
# 5 5
# 6 10
# 7 5
# 8 21
# 9 32
# 10 12
# 11 5
# 12 5
# 13 5

# %%
boxs = [10, 28, 5, 10, 5, 5, 10, 5, 21, 32, 12, 5, 5, 5]

for i in range(len(boxs)):
    print(boxs[i])
# Out:
# 10
# 28
# 5
# 10
# 5
# 5
# 10
# 5
# 21
# 32
# 12
# 5
# 5
# 5
