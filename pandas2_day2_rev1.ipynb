# %%
import pandas as pd
s = pd.Series([10, 20, 30, 40, 50])
print(s.head(3))
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
for i in range(n):
    print()

# %%
n=5
for i in range(n):
    print("*")
# Out:
# *
# *
# *
# *
# *

# %%
for i in range(5):
    print(i*"*")
    # print()
# Out:
# *
# **
# ***
# ****

# %%
print(s.head(2))
# Out:
# 0    10
# 1    20
# dtype: int64

# %%
print(s.tail(2))
# Out:
# 3    40
# 4    50
# dtype: int64

# %%
print(s.describe())
# Out:
# count     5.000000
# mean     30.000000
# std      15.811388
# min      10.000000
# 25%      20.000000
# 50%      30.000000
# 75%      40.000000
# max      50.000000
# dtype: float64

# %%
print(s.index)
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
print(s.values)
# Out:
# [10 20 30 40 50]

# %%
renamed = s.rename({0: 'a', 1: 'b'})
print(renamed)
# Out:
# a    10
# b    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
print(s.drop(2))
# Out:
# 0    10
# 1    20
# 3    40
# 4    50
# dtype: int64

# %%
popped = s.pop(2)
print(popped)
# Out:
# 30

# %%
print(s.replace(40, 99))
# Out:
# 0    10
# 1    20
# 3    99
# 4    50
# dtype: int64

# %%
# Statistics and Analysis
print(s.sum())
print(s.mean())
print(s.std())
print(s.min())
print(s.max())
# Out:
# 120
# 30.0
# 18.257418583505537
# 10
# 50

# %%
print(s.map(lambda x: x * 2))
# Out:
# 0     20
# 1     40
# 3     80
# 4    100
# dtype: int64

# %%
print(s.apply(str))
# Out:
# 0    10
# 1    20
# 3    40
# 4    50
# dtype: object
