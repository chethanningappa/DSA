# %%
b=1.5
type(b)
# Out:
# float

# %%
False and False
# Out:
# False

# %%
True and False
# Out:
# False

# %%
True or False
# Out:
# True

# %%
False or True
# Out:
# True

# %%
not True
# Out:
# False

# %%
not False
# Out:
# True
